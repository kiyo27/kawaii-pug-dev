# %%
import pandas as pd

# %%
df = pd.read_csv('result.csv')
df
# Out:
#    shape_edge shape_eyes shape_mouth color_base  color_eyes  color_ears  \
# 0       basic   sleeping    sleeping      basic         NaN         NaN
# 1       basic      basic       basic      basic         NaN         NaN
# 2       basic   sleeping    sleeping      basic         NaN         NaN
# 3       basic      basic       basic      basic         NaN         NaN
# 4       basic      basic       basic      basic         NaN         NaN
# ..        ...        ...         ...        ...         ...         ...
# 95      basic      basic       basic      basic         NaN         NaN
# 96      basic      basic       basic      basic         NaN         NaN
# 97      basic      basic       basic      basic         NaN         NaN
# 98      basic      basic       basic      basic         NaN         NaN
# 99      basic      basic       basic      basic         NaN         NaN
#
#    attributes_face attributes_head attributes_neck attributes_mouth  \
# ...
