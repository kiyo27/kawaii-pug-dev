# %%
import pandas as pd

# %%
df = pd.read_csv('result.csv')
df
# Out:
#    shape_edge shape_eyes shape_mouth color_base  color_eyes  color_ears  \
# 0       basic   sleeping    sleeping      basic         NaN         NaN
# 1       basic      basic       basic      basic         NaN         NaN
# 2       basic   sleeping    sleeping      basic         NaN         NaN
# 3       basic      basic       basic      basic         NaN         NaN
# 4       basic      basic       basic      basic         NaN         NaN
# 5       basic   sleeping    sleeping      basic         NaN         NaN
# 6       basic      basic       basic      basic         NaN         NaN
# 7       basic   sleeping    sleeping      basic         NaN         NaN
# 8       basic      basic       basic      basic         NaN         NaN
# 9       basic      basic       basic      basic         NaN         NaN
# 10      basic      basic       basic      basic         NaN         NaN
# 11      basic   sleeping    sleeping      basic         NaN         NaN
# ...

# %%
df['attributes_head'].value_counts()
# Out:
# pilot-helmet       12
# beanie             11
# welding-goggles    11
# Name: attributes_head, dtype: int64
